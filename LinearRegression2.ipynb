# %%
import numpy as np

# %%
x = np.array([2,5,7,8,9,10,23,45])
y = np.array([13,15,20,34,36,56,66,78])

# %%
#x_i = np.sum(x) 
s_x = np.sum(x)
s_y = np.sum(y)
s_xy = np.sum(x*y) #np.dot(x,y)
s_xx = np.sum(x*x)
n =len(x)

# %%
# x_i
# y_i = np.sum(y)

# xi_y_i = x_i * y_i

# xi_yi = x * y

# sum_xiyi = np.sum(xi_yi)

# xi2 = np.sum(x)
# xi2 = xi2 **2

#num_b1 = s_x * s_y /n - s_xy

# %%
b1 = ((s_x * s_y / n) - s_xy) / (((s_x**2)/n) - s_xx)

# %%
b1
# Out:
# 1.5031881454872025

# %%
b0 = (s_y - b1*s_x)/n

# %%
b0
# Out:
# 19.269061517736866

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
x.shape
# Out:
# (8,)

# %%
lr.fit(x.reshape(-1,1),y) #temporary reshape x #you can permanently reshape it with reshape()
# Out:
# LinearRegression()

# %%
lr.intercept_ , lr.coef_
# Out:
# (19.26906151773686, array([1.50318815]))
